# %% [markdown]
# # Data Cleaning & Integration

# %% [markdown]
# ## Extract from zip folder to dataframes.

# %%
# Import Dependencies
import os
import pandas as pd
import numpy as np
from zipfile import ZipFile
import datetime as datetime

# %%
# Unzip folder and extract each csv file into dataframes.
zf = ZipFile(r'C:\Users\haiyo\DC\Construction_Project_Management_Report_Analysis\Raw_Data\archive (1).zip')
Forms_df = pd.read_csv(zf.open('Construction_Data_PM_Forms_All_Projects.csv'))
Tasks_df = pd.read_csv(zf.open('Construction_Data_PM_Tasks_All_Projects.csv'))

# %% [markdown]
# ## Inspect, clean, and Transform Forms dataframe.

# %%
# Check for basic column and row makeup, and look for any missing data.
Forms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10254 entries, 0 to 10253
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ref                  10254 non-null  object
#  1   Status               10254 non-null  object
#  2   Location             10254 non-null  object
#  3   Name                 10254 non-null  object
#  4   Created              10254 non-null  object
#  5   Type                 10254 non-null  object
#  6   Status Changed       10254 non-null  object
#  7   Open Actions         10254 non-null  int64
#  8   Total Actions        10254 non-null  int64
#  9   Association          2098 non-null   object
#  10  OverDue              10254 non-null  bool
#  11  Images               10254 non-null  bool
#  12  Comments             10254 non-null  bool
#  13  Documents            9450 non-null   object
#  14  Project              10254 non-null  int64
#  15  Report Forms Status  10252 non-null  object
#  16  Report Forms Group   10250 non-null  object
# dtypes: bool(3), int64(3), object(11)
# memory usage: 1.1+ MB

# %%
# Check the Association column to evaluate whether the whole column could be dropped instead on removing non-null value rows.
print(Forms_df['Association'].value_counts())
# Out:
# parent    1702
# child      396
# Name: Association, dtype: int64

# %%
# As there is no additional information to discover the relationship between the parent and child documents, the column was dropped altogether.
Forms_df = Forms_df.drop('Association', axis=1)

# %%
# Drop rows that contain at least one null value.
Forms_df = Forms_df.dropna()
Forms_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9444 entries, 0 to 10253
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ref                  9444 non-null   object
#  1   Status               9444 non-null   object
#  2   Location             9444 non-null   object
#  3   Name                 9444 non-null   object
#  4   Created              9444 non-null   object
#  5   Type                 9444 non-null   object
#  6   Status Changed       9444 non-null   object
#  7   Open Actions         9444 non-null   int64
#  8   Total Actions        9444 non-null   int64
#  9   OverDue              9444 non-null   bool
#  10  Images               9444 non-null   bool
#  11  Comments             9444 non-null   bool
#  12  Documents            9444 non-null   object
#  13  Project              9444 non-null   int64
#  14  Report Forms Status  9444 non-null   object
#  15  Report Forms Group   9444 non-null   object
# dtypes: bool(3), int64(3), object(10)
# memory usage: 1.0+ MB

# %%
Forms_df.head(15)
# Observations & Tasks:

## How many forms are 'Opened', 'Open / Ongoing Works', etc. 
## What is the percentage breakdown of the 'Location', 'Report Forms Group', or 'Name' of the forms?
## There is no obvious pattern with 'Location', too many data points.
## Are there any forms that have different 'Created' and 'Status Changed' dates? What about 'OverDue'?
## Check if 'Project' is uniform. 
## Check if any forms were closed without a '0' for 'Open Actions', no alarming signs in 'OverDue', and 'Report Forms Status'.
## Change date format to datetime for conventional US reports.
# Out:
#             Ref                    Status  \
# 0     F145185.4                    Opened
# 1     F1.495500      Open / Ongoing Works
# 2     F1.495499      Open / Ongoing Works
# 3     F1.495498      Open / Ongoing Works
# 4     F1.495496      Open / Ongoing Works
# 5     F1.495479      Open / Ongoing Works
# 6    F124541.22      Open / Ongoing Works
# 7    F124541.21      Open / Ongoing Works
# 8     F1.495343  Subcontractor Signed Off
# 9     F1.495319      Open / Ongoing Works
# 10    F1.495317      Open / Ongoing Works
# 11    F1.495311      Open / Ongoing Works
# 12    F1.495286      Open / Ongoing Works
# 13  F116412.544      Open / Ongoing Works
# 14    F1.495253      Open / Ongoing Works
#
#                                              Location  \
# 0   01 Daily Site Diary>Site Management>JPC Projec...
# 1   02 Daily Work Plan>Site Management>JPC Project...
# 2   02 Daily Work Plan>Site Management>JPC Project...
# 3   02 Daily Work Plan>Site Management>JPC Project...
# 4   02 Daily Work Plan>Site Management>JPC Project...
# 5   02 Daily Work Plan>Site Management>JPC Project...
# 6   02 Daily Work Plan>Site Management>JPC Project...
# 7   02 Daily Work Plan>Site Management>JPC Project...
# 8   02 Daily Work Plan>Site Management>JPC Project...
# 9   02 Daily Work Plan>Site Management>JPC Project...
# 10  02 Daily Work Plan>Site Management>JPC Project...
# 11  02 Daily Work Plan>Site Management>JPC Project...
# 12  02 Daily Work Plan>Site Management>JPC Project...
# 13  2nd to 3rd Floor>4. Courtyard (South Elevation...
# 14  02 Daily Work Plan>Site Management>JPC Project...
#
#                                     Name     Created  \
# 0          1328 CM-SM-FRM-001 Site Diary  15/09/2020
# 1         SM-FRM-SUB-101 Daily Work Plan  15/09/2020
# 2         SM-FRM-SUB-101 Daily Work Plan  15/09/2020
# 3         SM-FRM-SUB-101 Daily Work Plan  15/09/2020
# 4         SM-FRM-SUB-101 Daily Work Plan  15/09/2020
# 5         SM-FRM-SUB-101 Daily Work Plan  15/09/2020
# 6         SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 7         SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 8         SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 9         SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 10        SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 11        SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 12        SM-FRM-SUB-101 Daily Work Plan  14/09/2020
# 13  QM-FRM-QC-009 Quality Control Record  14/09/2020
# 14        SM-FRM-SUB-101 Daily Work Plan  14/09/2020
#
#                          Type Status Changed  Open Actions  Total Actions  \
# 0             Site Management     15/09/2020             0              0
# 1   Subcontractor Inspections     15/09/2020             0              0
# 2   Subcontractor Inspections     15/09/2020             0              0
# 3   Subcontractor Inspections     15/09/2020             0              0
# 4   Subcontractor Inspections     15/09/2020             0              0
# 5   Subcontractor Inspections     15/09/2020             0              0
# 6   Subcontractor Inspections     14/09/2020             0              0
# 7   Subcontractor Inspections     14/09/2020             0              0
# 8   Subcontractor Inspections     14/09/2020             0              0
# 9   Subcontractor Inspections     14/09/2020             0              0
# 10  Subcontractor Inspections     14/09/2020             0              0
# 11  Subcontractor Inspections     14/09/2020             0              0
# 12  Subcontractor Inspections     14/09/2020             0              0
# 13         Quality 00 General     14/09/2020             0              0
# 14  Subcontractor Inspections     14/09/2020             0              0
#
#     OverDue  Images  Comments Documents  Project Report Forms Status  \
# 0     False    True     False     False     1328                Open
# 1     False   False     False     False     1328                Open
# 2     False   False     False     False     1328                Open
# 3     False   False     False     False     1328                Open
# 4     False   False     False     False     1328                Open
# 5     False   False     False     False     1328                Open
# 6     False   False     False     False     1328                Open
# 7     False   False     False     False     1328                Open
# 8     False   False     False     False     1328              Closed
# 9     False   False     False     False     1328                Open
# 10    False   False     False     False     1328                Open
# 11    False   False     False     False     1328                Open
# 12    False   False     False     False     1328                Open
# 13    False    True     False     False     1328                Open
# 14    False   False     False     False     1328                Open
#
#    Report Forms Group
# 0     Site Management
# 1       Subcontractor
# 2       Subcontractor
# 3       Subcontractor
# 4       Subcontractor
# 5       Subcontractor
# 6       Subcontractor
# 7       Subcontractor
# 8       Subcontractor
# 9       Subcontractor
# 10      Subcontractor
# 11      Subcontractor
# 12      Subcontractor
# 13            Quality
# 14      Subcontractor

# %%
# Convert date object column into datetime format.
Forms_df['Created'] = pd.to_datetime(Forms_df['Created'])
Forms_df['Status Changed'] = pd.to_datetime(Forms_df['Status Changed'])

# %%
print(Forms_df['Project'].value_counts())
# Out:
# 1328    4039
# 1330    2149
# 1329    1210
# 1340     744
# 1338     510
# 1343     396
# 1345     396
# Name: Project, dtype: int64

# %%
print(Forms_df['Report Forms Group'].value_counts())
# Out:
# Quality            4105
# Site Management    2795
# Safety             1937
# Subcontractor       465
# Design Team         142
# Name: Report Forms Group, dtype: int64

# %%
print(Forms_df['Type'].value_counts())
# Out:
# Site Management              2771
# Safety Forms                 1935
# Quality 01 Structural        1604
# Quality 02 Architectural     1265
# Quality 00 General           1142
# Subcontractor Inspections     465
# Design Team / BC(A)R          142
# Quality 04 MEP Services        48
# Quality 03 Civil               27
# BU - Head Office               24
# Inspection                     19
# Permits                         2
# Name: Type, dtype: int64

# %%
print(Forms_df['Status'].value_counts())
# Out:
# Closed                                   3083
# Open / Ongoing Works                     1634
# Completed and signed off                 1290
# Closed JPC Sign Off                       956
# Closed JPC Reviewed                       864
# JPC Signed Off / Closed                   311
# JPC Sign Off / Closed                     256
# Opened                                    188
# Ready to be delivered                     186
# JPC Inspected                             181
# 3rd Party Sign Off - Closed               127
# JPC Sign Off                              111
# Subcontractor Signed Off                   58
# Works Complete / Resolved                  58
# Open                                       54
# Test Results Required                      31
# In Process / Manufactor                    15
# Notification                               15
# Delivered to site                          10
# In Manufactor                               4
# Permit to Unload / Dismantle (Closed)       4
# Rejected / Action Required                  4
# Works Complete                              3
# Closed (Design Team Acceptance)             1
# Name: Status, dtype: int64

# %%
# Normalize similar 'Status' items.
Forms_df['Status'] = Forms_df['Status'].replace(['JPC Signed Off / Closed','JPC Sign Off / Closed','Closed (Design Team Acceptance)', 'Closed JPC Reviewed', 'Closed JPC Sign Off'],['Closed JPC Sign Off / Reviewed', 'Closed JPC Sign Off / Reviewed', 'Closed', 'Closed JPC Sign Off / Reviewed', 'Closed JPC Sign Off / Reviewed'])
Forms_df['Status'] = Forms_df['Status'].replace(['Opened','Works Complete'],['Open', 'Works Complete / Resolved'])
Forms_df['Status'] = Forms_df['Status'].replace(['3rd Party Sign Off - Closed','Permit to Unload / Dismantle (Closed)'],['Closed 3rd Party Sign Off', 'Closed Permit to Unload / Dismantle'])


print(Forms_df['Status'].value_counts())
# Out:
# Closed                                 3084
# Closed JPC Sign Off / Reviewed         2387
# Open / Ongoing Works                   1634
# Completed and signed off               1290
# Open                                    242
# Ready to be delivered                   186
# JPC Inspected                           181
# Closed 3rd Party Sign Off               127
# JPC Sign Off                            111
# Works Complete / Resolved                61
# Subcontractor Signed Off                 58
# Test Results Required                    31
# In Process / Manufactor                  15
# Notification                             15
# Delivered to site                        10
# Closed Permit to Unload / Dismantle       4
# Rejected / Action Required                4
# In Manufactor                             4
# Name: Status, dtype: int64

# %%
print(Forms_df['Location'].value_counts())
# Out:
# 01 Daily Site Diary>Site Management>JPC Project Management                                            1346
# EHS Inspections>JPC Project Management                                                                 608
# Daily Site Diary & Allocation Sheets>JPC Project Management                                            581
# 02 Daily Work Plan>Site Management>JPC Project Management                                              446
# 01 Inspections>EHS Management>JPC Project Management                                                   377
#                                                                                                       ...
# RM.05.564>Area 3>5th Floor Plan>Block 3>ITP 02 Architectural & M&E Services>QC & BC(A)R                  1
# ESB Retaining Wall 02>Civil & External Works>ITP 01 Civil & Structural>Quality Control & BC(A)R          1
# Meeting Records>JPC Project Management                                                                   1
# 19-L3-48 Office 8>Offices>3rd Floor Plan>ITP 02 Architectural>Quality Control & BC(A)R                   1
# 19-L2-50 Conf Room 3>Conference Rooms>2nd Floor Plan>ITP 02 Architectural>Quality Control & BC(A)R       1
# Name: Location, Length: 753, dtype: int64

# %%
print(Forms_df['Name'].value_counts())
# Out:
# SM-FRM-001 Daily Site Diary                           1161
# EHS Managment Inspection - Daily                       991
# QM-FRM-QC-009 Quality Control Record                   502
# SM-FRM-SUB-101 Daily Work Plan                         449
# 1328 CM-SM-FRM-001 Site Diary                          399
#                                                       ...
# QM-FRM-BCAR-600 Assigned Certifier BCAR Inspection       1
# SM-FRM-005 Permit to Enter                               1
# CM-EHS-FRM-110 EHS Weekly Inspection                     1
# JPC-QC-CL-106 Pile Mat Inspection                        1
# EHS-FRM-SUB-001 Weekly EHS Submission Record             1
# Name: Name, Length: 118, dtype: int64

# %% [markdown]
# ## Inspect, clean, and Transform Tasks dataframe.

# %%
# Get dataframe info.
Tasks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12424 entries, 0 to 12423
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ref             12424 non-null  object
#  1   Status          12424 non-null  object
#  2   Location        12424 non-null  object
#  3   Description     12424 non-null  object
#  4   Created         12424 non-null  object
#  5   Target          2568 non-null   float64
#  6   Type            12424 non-null  object
#  7   To Package      11382 non-null  object
#  8   Status Changed  12424 non-null  object
#  9   Association     9483 non-null   object
#  10  OverDue         12424 non-null  bool
#  11  Images          12272 non-null  object
#  12  Comments        11902 non-null  object
#  13  Documents       11780 non-null  object
#  14  Priority        2366 non-null   object
#  15  Cause           9683 non-null   object
#  16  project         12424 non-null  int64
#  17  Report Status   12424 non-null  object
#  18  Task Group      12374 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(16)
# memory usage: 1.7+ MB

# %%
# Drop rows with at least one null value.
Tasks_test_df = Tasks_df.dropna()
Tasks_test_df.info()

# Finding: do not use dropna() as there will too few datasets for a potential machine learning analysis.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 301 to 10036
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ref             69 non-null     object
#  1   Status          69 non-null     object
#  2   Location        69 non-null     object
#  3   Description     69 non-null     object
#  4   Created         69 non-null     object
#  5   Target          69 non-null     float64
#  6   Type            69 non-null     object
#  7   To Package      69 non-null     object
#  8   Status Changed  69 non-null     object
#  9   Association     69 non-null     object
#  10  OverDue         69 non-null     bool
#  11  Images          69 non-null     object
#  12  Comments        69 non-null     object
#  13  Documents       69 non-null     object
#  14  Priority        69 non-null     object
#  15  Cause           69 non-null     object
#  16  project         69 non-null     int64
#  17  Report Status   69 non-null     object
#  18  Task Group      69 non-null     object
# dtypes: bool(1), float64(1), int64(1), object(16)
# memory usage: 10.3+ KB

# %%
Tasks_df.head(30)
# Observations & Tasks: 
# Change all date formats from the European DD/MM/YYYY to YYYY/MM/DD. 
# 'Target' column is in a date number format that should be converted to date format.
# 'Association' column is the sort of action to take on the line item.
# Check if any 'OverDue' items were 'True', and if 'Created' and 'Target' columns have any relationship.
# What were 'Priority' tasks? Any relations to 'Cause, 'Task Group', 'OverDue' or 'Association'?
# Check null values from each column.
# Out:
#             Ref                Status  \
# 0   T1.23963030                  Open
# 1   T116412.200                Closed
# 2    T141663.27  EHS Good Observation
# 3   T116412.199                Closed
# 4    T141663.26  EHS Good Observation
# 5   T116412.198                Closed
# 6    T141663.25  EHS Good Observation
# 7   T116412.197                Closed
# 8    T141663.24  EHS Good Observation
# 9    T141663.23                  Open
# 10   T141663.22                  Open
# 11   T141663.21                  Open
# 12   T141663.20                  Open
# 13   T141663.19                  Open
# 14   T141663.18                  Open
# 15   T141663.17                  Open
# 16   T141663.16                  Open
# 17   T141663.15                  Open
# 18   T141663.14                  Open
# 19   T141663.13                  Open
# 20  T116412.196  Open / Ongoing Works
# 21  T116412.195  Open / Ongoing Works
# 22  T131475.100  Open / Ongoing Works
# 23   T107663.55  EHS Good Observation
# 24   T107663.54                  Open
# 25   T131475.99                  Open
# 26   T107663.53                Closed
# 27   T131475.98                  Open
# 28   T107663.52                Closed
# 29   T107663.51                Closed
#
#                                              Location  \
# 0   JPC Project Management>EHS Management>01 Inspe...
# 1   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 2   JPC Project Management>EHS Management>01 Inspe...
# 3   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 4   JPC Project Management>EHS Management>01 Inspe...
# 5   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 6   JPC Project Management>EHS Management>01 Inspe...
# 7   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 8   JPC Project Management>EHS Management>01 Inspe...
# 9   JPC Project Management>EHS Management>01 Inspe...
# 10  JPC Project Management>EHS Management>01 Inspe...
# 11  JPC Project Management>EHS Management>01 Inspe...
# 12  JPC Project Management>EHS Management>01 Inspe...
# 13  JPC Project Management>EHS Management>01 Inspe...
# 14  JPC Project Management>EHS Management>01 Inspe...
# 15  JPC Project Management>EHS Management>01 Inspe...
# 16  JPC Project Management>EHS Management>01 Inspe...
# 17  JPC Project Management>EHS Management>01 Inspe...
# 18  JPC Project Management>EHS Management>01 Inspe...
# 19  JPC Project Management>EHS Management>01 Inspe...
# 20  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 21  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 22              JPC Project Management>EHS Management
# 23  JPC Project Management>EHS Management>01 Inspe...
# 24  JPC Project Management>EHS Management>01 Inspe...
# 25              JPC Project Management>EHS Management
# 26  JPC Project Management>EHS Management>01 Inspe...
# 27              JPC Project Management>EHS Management
# 28  JPC Project Management>EHS Management>01 Inspe...
# 29  JPC Project Management>EHS Management>01 Inspe...
#
#                                           Description     Created   Target  \
# 0   task raised in incorrect location of this form...  14/09/2020      NaN
# 1                                              Metsec  14/09/2020      NaN
# 2   Good clear exclusion zones and access through ...  14/09/2020      NaN
# 3                                            RC walls  14/09/2020      NaN
# 4   block 02 working level has good housekeeping, ...  14/09/2020      NaN
# 5                                          A3 Roofing  14/09/2020      NaN
# 6   operaiver using hand sanitizer points onsite. ...  14/09/2020      NaN
# 7                                       Tyvec install  14/09/2020      NaN
# 8             number of operative fully pee compliant  14/09/2020      NaN
# 9   doors to pods removed. to be reviewed to ensur...  14/09/2020      NaN
# 10  entry room to mass climber cluttered with mate...  14/09/2020      NaN
# 11                                  toe board missing  14/09/2020      NaN
# 12  number of operative not wearing full PPE (glas...  14/09/2020      NaN
# 13  sanitiser point could be erected in block 01, ...  14/09/2020      NaN
# 14  no safety station upper floors block 03/04. th...  14/09/2020      NaN
# 15  ladder tag dated for a month. this should be a...  14/09/2020      NaN
# 16                                      no ladder tag  14/09/2020      NaN
# 17                                      no ladder tag  14/09/2020      NaN
# 18  review of level 08 gaurd rail required around ...  14/09/2020      NaN
# 19  drinking bottles from contractors not being di...  14/09/2020      NaN
# 20                Flatpack duct not sealed laterally.  14/09/2020  44094.0
# 21                Flatpack duct not sealed laterally.  14/09/2020  44094.0
# 22  Temporary lighting required block 4, levels 5,...  11/09/2020  44091.0
# 23                     Good clear walkways Block 1 L5  11/09/2020      NaN
# 24  Sweeping of rubbish into corners on areas wher...  11/09/2020      NaN
# 25               Cables to be pinned up appropriately  11/09/2020      NaN
# 26                Poor housekeeping. Needs to skipped  11/09/2020      NaN
# 27               Cables to be tidied at transformers.  11/09/2020      NaN
# 28                                         Food waste  11/09/2020      NaN
# 29               Storage of materials in Hodgins area  11/09/2020      NaN
#
#                                         Type             To Package  \
# 0      Safety Notice (Amber) - General Issue        Main Contractor
# 1                       JPC - Progress Photo  Ceilings & Partitions
# 2   Safety Notice (Green) - Good Observation        Main Contractor
# 3                       JPC - Progress Photo       Precast Concrete
# 4   Safety Notice (Green) - Good Observation       Precast Concrete
# 5                       JPC - Progress Photo                Roofing
# 6   Safety Notice (Green) - Good Observation  Ceilings & Partitions
# 7                       JPC - Progress Photo     Cladding & Roofing
# 8   Safety Notice (Green) - Good Observation        Main Contractor
# 9      Safety Notice (Amber) - General Issue        Main Contractor
# 10     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 11     Safety Notice (Amber) - General Issue            Scaffolding
# 12     Safety Notice (Amber) - General Issue        Main Contractor
# 13     Safety Notice (Amber) - General Issue        Main Contractor
# 14     Safety Notice (Amber) - General Issue        Main Contractor
# 15     Safety Notice (Amber) - General Issue             Mechanical
# 16     Safety Notice (Amber) - General Issue    Temporary Electrics
# 17     Safety Notice (Amber) - General Issue       Precast Concrete
# 18     Safety Notice (Amber) - General Issue            Scaffolding
# 19     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 20         JPC - Quality Defect (compliance)  Ceilings & Partitions
# 21         JPC - Quality Defect (compliance)  Ceilings & Partitions
# 22                         JPC - Works To Go    Temporary Electrics
# 23  Safety Notice (Green) - Good Observation        Main Contractor
# 24     Safety Notice (Amber) - General Issue       Precast Concrete
# 25     Safety Notice (Amber) - General Issue    Temporary Electrics
# 26     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 27     Safety Notice (Amber) - General Issue    Temporary Electrics
# 28     Safety Notice (Amber) - General Issue             Mechanical
# 29     Safety Notice (Amber) - General Issue        Curtain Walling
#
#    Status Changed Association  OverDue Images Comments Documents  \
# 0      14/09/2020  FormAnswer    False    NaN      NaN       NaN
# 1      14/09/2020         NaN    False   True    False     False
# 2      14/09/2020  FormAnswer    False   True    False     False
# 3      14/09/2020         NaN    False   True    False     False
# 4      14/09/2020  FormAnswer    False   True    False     False
# 5      14/09/2020         NaN    False   True    False     False
# 6      14/09/2020  FormAnswer    False   True    False     False
# 7      14/09/2020         NaN    False   True    False     False
# 8      14/09/2020  FormAnswer    False  False    False     False
# 9      14/09/2020  FormAnswer    False   True    False     False
# 10     14/09/2020  FormAnswer    False   True    False     False
# 11     14/09/2020  FormAnswer    False   True    False     False
# 12     14/09/2020  FormAnswer    False  False    False     False
# 13     14/09/2020         NaN    False   True    False     False
# 14     14/09/2020         NaN    False   True    False     False
# 15     14/09/2020  FormAnswer    False   True    False     False
# 16     14/09/2020  FormAnswer    False   True    False     False
# 17     14/09/2020  FormAnswer    False   True    False     False
# 18     14/09/2020  FormAnswer    False   True    False     False
# 19     14/09/2020  FormAnswer    False   True    False     False
# 20     14/09/2020  FormAnswer    False   True     True     False
# 21     14/09/2020  FormAnswer    False   True     True     False
# 22     11/09/2020  FormAnswer    False   True    False     False
# 23     11/09/2020  FormAnswer    False   True    False     False
# 24     11/09/2020  FormAnswer    False   True    False     False
# 25     11/09/2020  FormAnswer    False   True    False     False
# 26     15/09/2020  FormAnswer    False   True    False     False
# 27     11/09/2020  FormAnswer    False   True    False     False
# 28     11/09/2020  FormAnswer    False   True    False     False
# 29     11/09/2020  FormAnswer    False   True    False     False
#
#                Priority                               Cause  project  \
# 0   Behavioural Failure        JPC - Safety - Documentation     1328
# 1                   NaN                                 NaN     1328
# 2                   NaN               JPC - Safety - Access     1328
# 3                   NaN                                 NaN     1328
# 4                   NaN        JPC - Safety - House Keeping     1328
# 5                   NaN                                 NaN     1328
# 6                   NaN   JPC - Safety - Welfare Facilities     1328
# 7                   NaN                                 NaN     1328
# 8                   NaN                  JPC - Safety - PPE     1328
# 9                   NaN               JPC - Safety - Access     1328
# 10  Behavioural Failure              JPC - Safety - Storage     1328
# 11  Behavioural Failure               JPC - Safety - Access     1328
# 12       System Failure                  JPC - Safety - PPE     1328
# 13                  NaN        JPC - Safety - Documentation     1328
# 14                  NaN   JPC - Safety - Welfare Facilities     1328
# 15  Behavioural Failure              JPC - Safety - Ladders     1328
# 16                  NaN        JPC - Safety - WAH Equipment     1328
# 17  Behavioural Failure              JPC - Safety - Ladders     1328
# 18       System Failure          JPC - Safety - Scaffolding     1328
# 19                  NaN        JPC - Safety - House Keeping     1328
# 20                  NaN         JPC - Quality - Workmanship     1328
# 21                  NaN         JPC - Quality - Workmanship     1328
# 22                  NaN                                 NaN     1328
# 23                  NaN               JPC - Safety - Access     1328
# 24  Behavioural Failure        JPC - Safety - House Keeping     1328
# 25                  NaN  JPC - Safety - Temporary Electrics     1328
# 26       System Failure        JPC - Safety - House Keeping     1328
# 27                  NaN           JPC - Safety - Electrical     1328
# 28  Behavioural Failure        JPC - Safety - House Keeping     1328
# 29       System Failure              JPC - Safety - Storage     1328
#
#    Report Status       Task Group
# 0           Open           Safety
# 1         Closed  Site Management
# 2         Closed           Safety
# 3         Closed  Site Management
# 4         Closed           Safety
# 5         Closed  Site Management
# 6         Closed           Safety
# 7         Closed  Site Management
# 8         Closed           Safety
# 9           Open           Safety
# 10          Open           Safety
# 11          Open           Safety
# 12          Open           Safety
# 13          Open           Safety
# 14          Open           Safety
# 15          Open           Safety
# 16          Open           Safety
# 17          Open           Safety
# 18          Open           Safety
# 19          Open           Safety
# 20          Open          Quality
# 21          Open          Quality
# 22          Open  Site Management
# 23        Closed           Safety
# 24          Open           Safety
# 25          Open           Safety
# 26        Closed           Safety
# 27          Open           Safety
# 28        Closed           Safety
# 29        Closed           Safety

# %%
print(Tasks_df['Status'].value_counts())
# Out:
# Closed                           6135
# EHS Good Observation             3343
# Open / Ongoing Works              683
# 3rd Party Sign Off - Closed       678
# Open                              558
# JPC Sign Off / Closed             473
# JPC Sign Off                      200
# Rejected / Action Required        124
# Closed JPC Reviewed                69
# Works Complete / Resolved          63
# JPC Signed Off / Closed            36
# Complete                           30
# JPC Inspected                      29
# 3rd Party Inspection - Closed       1
# Delivered - Material onsite         1
# Photo Record                        1
# Name: Status, dtype: int64

# %%
Tasks_df['Status'] = Tasks_df['Status'].replace(['Closed JPC Reviewed','JPC Signed Off / Closed'],['JPC Reviewed / Closed', 'JPC Sign Off / Closed'])
Tasks_df['Status'] = Tasks_df['Status'].replace(['Complete','3rd Party Inspection - Closed'],['Works Complete / Resolved', '3rd Party Sign Off - Closed'])

print(Tasks_df['Status'].value_counts())
# Out:
# Closed                         6135
# EHS Good Observation           3343
# Open / Ongoing Works            683
# 3rd Party Sign Off - Closed     679
# Open                            558
# JPC Sign Off / Closed           509
# JPC Sign Off                    200
# Rejected / Action Required      124
# Works Complete / Resolved        93
# JPC Reviewed / Closed            69
# JPC Inspected                    29
# Delivered - Material onsite       1
# Photo Record                      1
# Name: Status, dtype: int64

# %%
print(Tasks_df['Type'].value_counts())
# Out:
# Safety Notice (Amber) - General Issue            5486
# Safety Notice (Green) - Good Observation         3343
# JPC - Progress Photo                              666
# JPC - Works To Go                                 506
# JPC - Quality Snag (aesthetic)                    351
# Design Team - BCAR Structural                     325
# JPC - Quality Defect (compliance)                 298
# Design Team - BCAR Architectural                  295
# Design Team - BCAR Assign Certifier               154
# Program Constraint Task (Last Planner)            152
# Quality - Snag (aesthetic)                         95
# JPC - Upcoming Work Planning                       89
# BCAR - Assign certifier                            84
# BCAR - Structural                                  73
# Quality - Good Observation                         70
# JPC - Good Quality Observation                     65
# Design Team - Works To Go                          61
# Safety Notice (Red) - Serious Issue                55
# Design Team - Good Quality Observation             49
# SubCon - Fire Stopping Record                      41
# Design Team - Snag (Non BC(A)R)                    35
# Quality - Works To Complete                        20
# Design Team - BCAR Mechanical                      20
# Quality - Defect (compliance)                      18
# Design Team - BCAR Electrical                      15
# JPC - BCAR Notification                            14
# Design Team Snag                                   11
# SubCon - Photo Record                               9
# Photo Record                                        6
# Design Team - Defect (Non BC(A)R)                   5
# BCAR - Architectural                                4
# BCAR - Electrical                                   3
# Design Team - BCAR Specialist Sub-Contractor        2
# JPC - Material Delivery                             1
# BCAR - Fire                                         1
# BCAR - Notification                                 1
# BCAR - Specialist Sub-Contractor                    1
# Name: Type, dtype: int64

# %%
# Check list of 'Priority' values, and see if it needs normalization.
print(Tasks_df['Priority'].value_counts())
# Out:
# Behavioural Failure                                                 951
# System Failure                                                      787
# Medium                                                              221
# High                                                                214
# Best Practice                                                        83
# System Failure - Deviation from RAMS / Manufacturer Instructions     31
# Low                                                                  29
# .                                                                    27
# 2 Week Look Ahead                                                    13
# Low (resolve within 2 weeks)                                          3
# 1 Week Look Ahead                                                     2
# Medium (resolve within 5 days)                                        2
# High (resolve within 48 hours)                                        2
# 1 Month Look Ahead                                                    1
# Name: Priority, dtype: int64

# %%
# Normalize 'Priority' column values: 'High' & 'High (resolve within 48 hours)'; 'Low' & 'Low (resolve within 2 weeks)'; and 'Medium' & 'Medium (resolve within 5 days)'.
Tasks_df['Priority'] = Tasks_df['Priority'].replace(['High'],'High (resolve within 48 hours)')
Tasks_df['Priority'] = Tasks_df['Priority'].replace(['Medium'],'Medium (resolve within 5 days)')
Tasks_df['Priority'] = Tasks_df['Priority'].replace(['Low'],'Low (resolve within 2 weeks)')
print(Tasks_df['Priority'].value_counts())
# Out:
# Behavioural Failure                                                 951
# System Failure                                                      787
# Medium (resolve within 5 days)                                      223
# High (resolve within 48 hours)                                      216
# Best Practice                                                        83
# Low (resolve within 2 weeks)                                         32
# System Failure - Deviation from RAMS / Manufacturer Instructions     31
# .                                                                    27
# 2 Week Look Ahead                                                    13
# 1 Week Look Ahead                                                     2
# 1 Month Look Ahead                                                    1
# Name: Priority, dtype: int64

# %%
print(Tasks_df['Comments'].value_counts())
# Out:
# False    10600
# True      1302
# Name: Comments, dtype: int64

# %%
print(Tasks_df['Images'].value_counts())
# Out:
# True     11549
# False      723
# Name: Images, dtype: int64

# %%
# Drop columns that have boolean information only for second-tier quality of information: 'Comments', 'Images'
Tasks_df = Tasks_df.drop(['Comments', 'Images'], axis=1)

# %%
# Convert date object column into datetime format.
Tasks_df['Created'] = pd.to_datetime(Tasks_df['Created'])
Tasks_df['Status Changed'] = pd.to_datetime(Tasks_df['Status Changed'])

Tasks_df.head(10)
# Out:
#            Ref                Status  \
# 0  T1.23963030                  Open
# 1  T116412.200                Closed
# 2   T141663.27  EHS Good Observation
# 3  T116412.199                Closed
# 4   T141663.26  EHS Good Observation
# 5  T116412.198                Closed
# 6   T141663.25  EHS Good Observation
# 7  T116412.197                Closed
# 8   T141663.24  EHS Good Observation
# 9   T141663.23                  Open
#
#                                             Location  \
# 0  JPC Project Management>EHS Management>01 Inspe...
# 1  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 2  JPC Project Management>EHS Management>01 Inspe...
# 3  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 4  JPC Project Management>EHS Management>01 Inspe...
# 5  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 6  JPC Project Management>EHS Management>01 Inspe...
# 7  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 8  JPC Project Management>EHS Management>01 Inspe...
# 9  JPC Project Management>EHS Management>01 Inspe...
#
#                                          Description    Created  Target  \
# 0  task raised in incorrect location of this form... 2020-09-14     NaN
# 1                                             Metsec 2020-09-14     NaN
# 2  Good clear exclusion zones and access through ... 2020-09-14     NaN
# 3                                           RC walls 2020-09-14     NaN
# 4  block 02 working level has good housekeeping, ... 2020-09-14     NaN
# 5                                         A3 Roofing 2020-09-14     NaN
# 6  operaiver using hand sanitizer points onsite. ... 2020-09-14     NaN
# 7                                      Tyvec install 2020-09-14     NaN
# 8            number of operative fully pee compliant 2020-09-14     NaN
# 9  doors to pods removed. to be reviewed to ensur... 2020-09-14     NaN
#
#                                        Type             To Package  \
# 0     Safety Notice (Amber) - General Issue        Main Contractor
# 1                      JPC - Progress Photo  Ceilings & Partitions
# 2  Safety Notice (Green) - Good Observation        Main Contractor
# 3                      JPC - Progress Photo       Precast Concrete
# 4  Safety Notice (Green) - Good Observation       Precast Concrete
# 5                      JPC - Progress Photo                Roofing
# 6  Safety Notice (Green) - Good Observation  Ceilings & Partitions
# 7                      JPC - Progress Photo     Cladding & Roofing
# 8  Safety Notice (Green) - Good Observation        Main Contractor
# 9     Safety Notice (Amber) - General Issue        Main Contractor
#
#   Status Changed Association  OverDue Documents             Priority  \
# 0     2020-09-14  FormAnswer    False       NaN  Behavioural Failure
# 1     2020-09-14         NaN    False     False                  NaN
# 2     2020-09-14  FormAnswer    False     False                  NaN
# 3     2020-09-14         NaN    False     False                  NaN
# 4     2020-09-14  FormAnswer    False     False                  NaN
# 5     2020-09-14         NaN    False     False                  NaN
# 6     2020-09-14  FormAnswer    False     False                  NaN
# 7     2020-09-14         NaN    False     False                  NaN
# 8     2020-09-14  FormAnswer    False     False                  NaN
# 9     2020-09-14  FormAnswer    False     False                  NaN
#
#                                Cause  project Report Status       Task Group
# 0       JPC - Safety - Documentation     1328          Open           Safety
# 1                                NaN     1328        Closed  Site Management
# 2              JPC - Safety - Access     1328        Closed           Safety
# 3                                NaN     1328        Closed  Site Management
# 4       JPC - Safety - House Keeping     1328        Closed           Safety
# 5                                NaN     1328        Closed  Site Management
# 6  JPC - Safety - Welfare Facilities     1328        Closed           Safety
# 7                                NaN     1328        Closed  Site Management
# 8                 JPC - Safety - PPE     1328        Closed           Safety
# 9              JPC - Safety - Access     1328          Open           Safety

# %%
# Convert 'Target' excel dates into datetime for uniformity.
Tasks_df['Target'] = Tasks_df['Target'].fillna(0)

import xlrd

def read_date(date):
    return xlrd.xldate.xldate_as_datetime(date, 0)

Tasks_df['Target'] = pd.to_datetime(Tasks_df['Target'].apply(read_date), errors='coerce')

# Replace '1899-12-31' date with null.
year = 1900
Tasks_df['Target'] = pd.to_datetime(Tasks_df['Target'], dayfirst=True, errors='coerce')
Tasks_df['Target'] = Tasks_df['Target'].mask(Tasks_df['Target'].dt.year < year)

# Check
Tasks_df.head(100)
# Out:
#             Ref                     Status  \
# 0   T1.23963030                       Open
# 1   T116412.200                     Closed
# 2    T141663.27       EHS Good Observation
# 3   T116412.199                     Closed
# 4    T141663.26       EHS Good Observation
# ..          ...                        ...
# 95  T118318.206  Works Complete / Resolved
# 96  T118318.205  Works Complete / Resolved
# 97  T118318.204       Open / Ongoing Works
# 98  T118318.203  Works Complete / Resolved
# 99  T118318.202                       Open
#
#                                              Location  \
# 0   JPC Project Management>EHS Management>01 Inspe...
# 1   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 2   JPC Project Management>EHS Management>01 Inspe...
# 3   QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 4   JPC Project Management>EHS Management>01 Inspe...
# ..                                                ...
# 95             JPC Project Management>Site Management
# 96             JPC Project Management>Site Management
# 97  JPC Project Management>EHS Management>01 Inspe...
# 98  JPC Project Management>EHS Management>01 Inspe...
# 99  JPC Project Management>EHS Management>01 Inspe...
#
#                                           Description    Created Target  \
# 0   task raised in incorrect location of this form... 2020-09-14    NaT
# 1                                              Metsec 2020-09-14    NaT
# 2   Good clear exclusion zones and access through ... 2020-09-14    NaT
# 3                                            RC walls 2020-09-14    NaT
# 4   block 02 working level has good housekeeping, ... 2020-09-14    NaT
# ..                                                ...        ...    ...
# 95                                 Housekeeping l2 A3 2020-08-09    NaT
# 96                  Sweeping bruses needed by errigal 2020-08-09    NaT
# 97                      Flat pack outside drying room 2020-08-09    NaT
# 98                House keeping needs to be addressed 2020-08-09    NaT
# 99        Ply bending causing a trip hazard ar stairs 2020-08-09    NaT
#
#                                         Type             To Package  \
# 0      Safety Notice (Amber) - General Issue        Main Contractor
# 1                       JPC - Progress Photo  Ceilings & Partitions
# 2   Safety Notice (Green) - Good Observation        Main Contractor
# 3                       JPC - Progress Photo       Precast Concrete
# 4   Safety Notice (Green) - Good Observation       Precast Concrete
# ..                                       ...                    ...
# 95     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 96     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 97                      JPC - Progress Photo             Mechanical
# 98     Safety Notice (Amber) - General Issue  Ceilings & Partitions
# 99     Safety Notice (Amber) - General Issue        Main Contractor
#
#    Status Changed Association  OverDue Documents             Priority  \
# 0      2020-09-14  FormAnswer    False       NaN  Behavioural Failure
# 1      2020-09-14         NaN    False     False                  NaN
# 2      2020-09-14  FormAnswer    False     False                  NaN
# 3      2020-09-14         NaN    False     False                  NaN
# 4      2020-09-14  FormAnswer    False     False                  NaN
# ..            ...         ...      ...       ...                  ...
# 95     2020-09-09  FormAnswer    False     False                  NaN
# 96     2020-09-09  FormAnswer    False     False                  NaN
# 97     2020-08-09  FormAnswer    False     False                  NaN
# 98     2020-10-09  FormAnswer    False     False                  NaN
# 99     2020-08-09  FormAnswer    False     False                  NaN
#
#                            Cause  project Report Status       Task Group
# 0   JPC - Safety - Documentation     1328          Open           Safety
# 1                            NaN     1328        Closed  Site Management
# 2          JPC - Safety - Access     1328        Closed           Safety
# 3                            NaN     1328        Closed  Site Management
# 4   JPC - Safety - House Keeping     1328        Closed           Safety
# ..                           ...      ...           ...              ...
# 95  JPC - Safety - House Keeping     1328          Open           Safety
# 96  JPC - Safety - House Keeping     1328          Open           Safety
# 97                           NaN     1328          Open  Site Management
# 98  JPC - Safety - House Keeping     1328          Open           Safety
# 99         JPC - Safety - Access     1328          Open           Safety
#
# [100 rows x 17 columns]

# %%
# Create two new columns to monitor variances (in calendar days) between 'Created' and 'Target' (named as 'tdCreated'), and 'Status Changed' and 'Target' (named as 'tdStatusChanged').
Tasks_df['tdCreated'] = Tasks_df['Target']-Tasks_df['Created']
Tasks_df['tdStatusChanged'] = Tasks_df['Target']-Tasks_df['Status Changed']

# Check
Tasks_df.head(10)
# Out:
#            Ref                Status  \
# 0  T1.23963030                  Open
# 1  T116412.200                Closed
# 2   T141663.27  EHS Good Observation
# 3  T116412.199                Closed
# 4   T141663.26  EHS Good Observation
# 5  T116412.198                Closed
# 6   T141663.25  EHS Good Observation
# 7  T116412.197                Closed
# 8   T141663.24  EHS Good Observation
# 9   T141663.23                  Open
#
#                                             Location  \
# 0  JPC Project Management>EHS Management>01 Inspe...
# 1  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 2  JPC Project Management>EHS Management>01 Inspe...
# 3  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 4  JPC Project Management>EHS Management>01 Inspe...
# 5  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 6  JPC Project Management>EHS Management>01 Inspe...
# 7  QC & BC(A)R>ITP 02 Architectural & M&E Service...
# 8  JPC Project Management>EHS Management>01 Inspe...
# 9  JPC Project Management>EHS Management>01 Inspe...
#
#                                          Description    Created Target  \
# 0  task raised in incorrect location of this form... 2020-09-14    NaT
# 1                                             Metsec 2020-09-14    NaT
# 2  Good clear exclusion zones and access through ... 2020-09-14    NaT
# 3                                           RC walls 2020-09-14    NaT
# 4  block 02 working level has good housekeeping, ... 2020-09-14    NaT
# 5                                         A3 Roofing 2020-09-14    NaT
# 6  operaiver using hand sanitizer points onsite. ... 2020-09-14    NaT
# 7                                      Tyvec install 2020-09-14    NaT
# 8            number of operative fully pee compliant 2020-09-14    NaT
# 9  doors to pods removed. to be reviewed to ensur... 2020-09-14    NaT
#
#                                        Type             To Package  \
# 0     Safety Notice (Amber) - General Issue        Main Contractor
# 1                      JPC - Progress Photo  Ceilings & Partitions
# 2  Safety Notice (Green) - Good Observation        Main Contractor
# 3                      JPC - Progress Photo       Precast Concrete
# 4  Safety Notice (Green) - Good Observation       Precast Concrete
# 5                      JPC - Progress Photo                Roofing
# 6  Safety Notice (Green) - Good Observation  Ceilings & Partitions
# 7                      JPC - Progress Photo     Cladding & Roofing
# 8  Safety Notice (Green) - Good Observation        Main Contractor
# 9     Safety Notice (Amber) - General Issue        Main Contractor
#
#   Status Changed Association  OverDue Documents             Priority  \
# 0     2020-09-14  FormAnswer    False       NaN  Behavioural Failure
# 1     2020-09-14         NaN    False     False                  NaN
# 2     2020-09-14  FormAnswer    False     False                  NaN
# 3     2020-09-14         NaN    False     False                  NaN
# 4     2020-09-14  FormAnswer    False     False                  NaN
# 5     2020-09-14         NaN    False     False                  NaN
# 6     2020-09-14  FormAnswer    False     False                  NaN
# 7     2020-09-14         NaN    False     False                  NaN
# 8     2020-09-14  FormAnswer    False     False                  NaN
# 9     2020-09-14  FormAnswer    False     False                  NaN
#
#                                Cause  project Report Status       Task Group  \
# 0       JPC - Safety - Documentation     1328          Open           Safety
# 1                                NaN     1328        Closed  Site Management
# 2              JPC - Safety - Access     1328        Closed           Safety
# 3                                NaN     1328        Closed  Site Management
# 4       JPC - Safety - House Keeping     1328        Closed           Safety
# 5                                NaN     1328        Closed  Site Management
# 6  JPC - Safety - Welfare Facilities     1328        Closed           Safety
# 7                                NaN     1328        Closed  Site Management
# 8                 JPC - Safety - PPE     1328        Closed           Safety
# 9              JPC - Safety - Access     1328          Open           Safety
#
#   tdCreated tdStatusChanged
# 0       NaT             NaT
# 1       NaT             NaT
# 2       NaT             NaT
# 3       NaT             NaT
# 4       NaT             NaT
# 5       NaT             NaT
# 6       NaT             NaT
# 7       NaT             NaT
# 8       NaT             NaT
# 9       NaT             NaT

# %% [markdown]
# ## Export out as excel files for Tableau.

# %%
Forms_df.to_excel (r'C:\Users\haiyo\DC\Construction_Project_Management_Report_Analysis\Cleaned_Data\Forms.xlsx', index = None, header=True)
Tasks_df.to_excel (r'C:\Users\haiyo\DC\Construction_Project_Management_Report_Analysis\Cleaned_Data\Tasks.xlsx', index = None, header=True)
